# %%
# Don't edit this cell!

import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

from summaryCode import blackMagic

# %% [markdown]
# # Summary of flight

# %% [markdown]
# (your description here)

# %% [markdown]
# # Cherry data

# %%
blackMagic('2021-10-24_Cherry_flight_data.csv', disreef1=305, disreef2=183, before=500, after=100)
# Out:
# State changes at times:  3695275.0  3720681.0  3743834.0  3757541.0  3792474.0

# %% [markdown]
# # Apple data

# %%
blackMagic('2021-10-24_Apple_flight_data.csv', disreef1=305, disreef2=183, before=500, after=100)
# Out:
# State changes at times:  3904660.0  3930092.0  3955096.0  3967850.0  3979125.0
