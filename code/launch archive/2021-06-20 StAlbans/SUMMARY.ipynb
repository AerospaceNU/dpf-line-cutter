# %%
# Don't edit this cell!

import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

from summaryCode import blackMagic

# %% [markdown]
# # Summary of flight

# %% [markdown]
# (your description here)

# %% [markdown]
# # Cherry data

# %%
blackMagic('2021-06-20_TRDCherryLineCutterFlash.csv', lineColor='b', after=1500)
# Out:
# State changes at times:  3971168.0  4031585.0  4079296.0  4091806.0  4107109.0

# %% [markdown]
# # Strawberry data

# %%
blackMagic('2021-06-20_TRDStrawberryLineCutterFlash.csv')
# Out:
# State changes at times:  3637210.0  3697699.0  3745379.0  3757951.0  3771636.0
