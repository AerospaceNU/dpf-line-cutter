# %%
# Don't edit this cell!

import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

from summaryCode import blackMagic

# %% [markdown]
# # Summary of test

# %% [markdown]
# We used the Willis elevator and set the "arming altitude" to be 10m. There were a few unsuccessful tests while we worked out issues. This is the data from our last two tests, which were both successful.

# %% [markdown]
# # First test data

# %%
blackMagic('ElevatorTestData1.csv', before=900, after=1000)
# Out:
# State changes at times:  33602.0  57178.0  57418.0  60478.0  61828.0

# %% [markdown]
# # Second test data

# %%
blackMagic('ElevatorTestData2.csv', lineColor='purple', before=600, after=500)
# Out:
# State changes at times:  23471.0  41018.0  41258.0  44318.0  45578.0
